# %%
from api import *

# %%
SPARK_API_ENDPOINT = "http://localhost:4040"
spark_app_id = "local-1717710582737"

# %%
spark_api = SparkRestAPI(base_url = SPARK_API_ENDPOINT, app_id = spark_app_id)

# %%
sql = spark_api.get_sql()
stage = spark_api.get_stage()
job = spark_api.get_job()

# %%
stage
# Out:
# [{'status': 'COMPLETE',
#   'stageId': 29,
#   'attemptId': 0,
#   'numTasks': 1,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 1,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 1,
#   'submissionTime': '2024-06-06T21:53:03.817GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:53:03.839GMT',
#   'completionTime': '2024-06-06T21:53:03.910GMT',
#   'executorDeserializeTime': 6,
#   'executorDeserializeCpuTime': 5946000,
#   'executorRunTime': 50,
#   'executorCpuTime': 38386000,
#   'resultSize': 3995,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 0,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 494,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 29146,
#   'shuffleReadBytes': 29146,
#   'shuffleReadRecords': 494,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'description': 'scan tiny files 3',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [73, 72, 71],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'SKIPPED',
#   'stageId': 28,
#   'attemptId': 0,
#   'numTasks': 494,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 0,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 0,
#   'executorDeserializeTime': 0,
#   'executorDeserializeCpuTime': 0,
#   'executorRunTime': 0,
#   'executorCpuTime': 0,
#   'resultSize': 0,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 0,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [70, 69, 67, 68],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 27,
#   'attemptId': 0,
#   'numTasks': 494,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 494,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 494,
#   'submissionTime': '2024-06-06T21:52:59.971GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:52:59.991GMT',
#   'completionTime': '2024-06-06T21:53:03.717GMT',
#   'executorDeserializeTime': 1028,
#   'executorDeserializeCpuTime': 485426000,
#   'executorRunTime': 33908,
#   'executorCpuTime': 9505452000,
#   'resultSize': 1060774,
#   'jvmGcTime': 1814,
#   'resultSerializationTime': 67,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 85974920,
#   'inputRecords': 3604627124,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 29146,
#   'shuffleWriteTime': 323428349,
#   'shuffleWriteRecords': 494,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'description': 'scan tiny files 3',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [70, 69, 67, 68],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 26,
#   'attemptId': 0,
#   'numTasks': 1,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 1,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 1,
#   'submissionTime': '2024-06-06T21:52:59.560GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:52:59.593GMT',
#   'completionTime': '2024-06-06T21:52:59.671GMT',
#   'executorDeserializeTime': 27,
#   'executorDeserializeCpuTime': 22631000,
#   'executorRunTime': 34,
#   'executorCpuTime': 11538000,
#   'resultSize': 1826,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 0,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'parquet at NativeMethodAccessorImpl.java:0',
#   'description': 'scan tiny files 3',
#   'details': 'org.apache.spark.sql.DataFrameReader.parquet(DataFrameReader.scala:563)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [66, 65],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 25,
#   'attemptId': 0,
#   'numTasks': 1,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 1,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 1,
#   'submissionTime': '2024-06-06T21:52:47.967GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:52:48.006GMT',
#   'completionTime': '2024-06-06T21:52:48.038GMT',
#   'executorDeserializeTime': 5,
#   'executorDeserializeCpuTime': 2758000,
#   'executorRunTime': 21,
#   'executorCpuTime': 13527000,
#   'resultSize': 3994,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 0,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 10,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 569,
#   'shuffleReadBytes': 569,
#   'shuffleReadRecords': 10,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'description': 'scan tiny files 2',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [64, 62, 63],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'SKIPPED',
#   'stageId': 24,
#   'attemptId': 0,
#   'numTasks': 10,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 0,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 0,
#   'executorDeserializeTime': 0,
#   'executorDeserializeCpuTime': 0,
#   'executorRunTime': 0,
#   'executorCpuTime': 0,
#   'resultSize': 0,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 0,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [61, 59, 58, 60],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 23,
#   'attemptId': 0,
#   'numTasks': 10,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 10,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 10,
#   'submissionTime': '2024-06-06T21:52:47.724GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:52:47.738GMT',
#   'completionTime': '2024-06-06T21:52:47.935GMT',
#   'executorDeserializeTime': 222,
#   'executorDeserializeCpuTime': 28860000,
#   'executorRunTime': 1456,
#   'executorCpuTime': 274458000,
#   'resultSize': 21188,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 4,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 92520,
#   'inputRecords': 100000000,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 569,
#   'shuffleWriteTime': 41147374,
#   'shuffleWriteRecords': 10,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'description': 'scan tiny files 2',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [61, 59, 58, 60],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 22,
#   'attemptId': 0,
#   'numTasks': 1,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 1,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 1,
#   'submissionTime': '2024-06-06T21:52:47.396GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:52:47.425GMT',
#   'completionTime': '2024-06-06T21:52:47.503GMT',
#   'executorDeserializeTime': 23,
#   'executorDeserializeCpuTime': 19610000,
#   'executorRunTime': 41,
#   'executorCpuTime': 9796000,
#   'resultSize': 1618,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 0,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'parquet at NativeMethodAccessorImpl.java:0',
#   'description': 'scan tiny files 2',
#   'details': 'org.apache.spark.sql.DataFrameReader.parquet(DataFrameReader.scala:563)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [57, 56],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 21,
#   'attemptId': 0,
#   'numTasks': 1,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 1,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 1,
#   'submissionTime': '2024-06-06T21:52:47.188GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:52:47.218GMT',
#   'completionTime': '2024-06-06T21:52:47.261GMT',
#   'executorDeserializeTime': 7,
#   'executorDeserializeCpuTime': 6516000,
#   'executorRunTime': 22,
#   'executorCpuTime': 20778000,
#   'resultSize': 3995,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 0,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 62,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 3658,
#   'shuffleReadBytes': 3658,
#   'shuffleReadRecords': 62,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'description': 'scan tiny files',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [55, 53, 54],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'SKIPPED',
#   'stageId': 20,
#   'attemptId': 0,
#   'numTasks': 62,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 0,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 0,
#   'executorDeserializeTime': 0,
#   'executorDeserializeCpuTime': 0,
#   'executorRunTime': 0,
#   'executorCpuTime': 0,
#   'resultSize': 0,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 0,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [52, 49, 50, 51],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 19,
#   'attemptId': 0,
#   'numTasks': 62,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 62,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 62,
#   'submissionTime': '2024-06-06T21:52:44.740GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:52:44.776GMT',
#   'completionTime': '2024-06-06T21:52:47.085GMT',
#   'executorDeserializeTime': 2063,
#   'executorDeserializeCpuTime': 260320000,
#   'executorRunTime': 19446,
#   'executorCpuTime': 3745153000,
#   'resultSize': 134281,
#   'jvmGcTime': 380,
#   'resultSerializationTime': 140,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 10760222,
#   'inputRecords': 450787193,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 3658,
#   'shuffleWriteTime': 61731402,
#   'shuffleWriteRecords': 62,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'description': 'scan tiny files',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [52, 49, 50, 51],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 18,
#   'attemptId': 0,
#   'numTasks': 1,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 1,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 1,
#   'submissionTime': '2024-06-06T21:52:43.769GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:52:43.831GMT',
#   'completionTime': '2024-06-06T21:52:44.150GMT',
#   'executorDeserializeTime': 76,
#   'executorDeserializeCpuTime': 68509000,
#   'executorRunTime': 201,
#   'executorCpuTime': 29051000,
#   'resultSize': 1869,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 8,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'parquet at NativeMethodAccessorImpl.java:0',
#   'description': 'scan tiny files',
#   'details': 'org.apache.spark.sql.DataFrameReader.parquet(DataFrameReader.scala:563)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [48, 47],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 17,
#   'attemptId': 0,
#   'numTasks': 20,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 20,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 20,
#   'submissionTime': '2024-06-06T21:52:02.652GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:52:02.702GMT',
#   'completionTime': '2024-06-06T21:52:04.712GMT',
#   'executorDeserializeTime': 1302,
#   'executorDeserializeCpuTime': 165671000,
#   'executorRunTime': 10784,
#   'executorCpuTime': 355069000,
#   'resultSize': 119244690,
#   'jvmGcTime': 909,
#   'resultSerializationTime': 138,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 210,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 89194207,
#   'shuffleReadBytes': 89194207,
#   'shuffleReadRecords': 4010,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'collect at /var/folders/qr/3fmt11j97gq73yrbx28qtl5w0000gn/T/ipykernel_86326/1254802928.py:18',
#   'description': 'skew',
#   'details': 'org.apache.spark.rdd.RDD.collect(RDD.scala:1048)\norg.apache.spark.api.python.PythonRDD$.collectAndServe(PythonRDD.scala:195)\norg.apache.spark.api.python.PythonRDD.collectAndServe(PythonRDD.scala)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [46, 45, 44],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 16,
#   'attemptId': 0,
#   'numTasks': 20,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 20,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 20,
#   'submissionTime': '2024-06-06T21:51:57.884GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:51:57.928GMT',
#   'completionTime': '2024-06-06T21:52:02.629GMT',
#   'executorDeserializeTime': 1299,
#   'executorDeserializeCpuTime': 116349000,
#   'executorRunTime': 40907,
#   'executorCpuTime': 3377096000,
#   'resultSize': 31421,
#   'jvmGcTime': 6710,
#   'resultSerializationTime': 70,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 89194207,
#   'shuffleWriteTime': 931349385,
#   'shuffleWriteRecords': 4010,
#   'name': 'reduceByKey at /var/folders/qr/3fmt11j97gq73yrbx28qtl5w0000gn/T/ipykernel_86326/1254802928.py:16',
#   'description': 'skew',
#   'details': 'org.apache.spark.rdd.RDD.<init>(RDD.scala:102)\norg.apache.spark.api.python.PairwiseRDD.<init>(PythonRDD.scala:126)\nsun.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)\nsun.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)\nsun.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)\njava.lang.reflect.Constructor.newInstance(Constructor.java:423)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:238)\npy4j.commands.ConstructorCommand.invokeConstructor(ConstructorCommand.java:80)\npy4j.commands.ConstructorCommand.execute(ConstructorCommand.java:69)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [43, 42, 39, 40, 41],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 668349280,
#    'JVMOffHeapMemory': 162433704,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 90832442,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 90832442,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 201636,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 143,
#    'MinorGCTime': 1189,
#    'MajorGCCount': 29,
#    'MajorGCTime': 2325,
#    'TotalGCTime': 3514},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 15,
#   'attemptId': 0,
#   'numTasks': 1,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 1,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 1,
#   'submissionTime': '2024-06-06T21:50:25.165GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:50:25.196GMT',
#   'completionTime': '2024-06-06T21:50:25.352GMT',
#   'executorDeserializeTime': 8,
#   'executorDeserializeCpuTime': 6401000,
#   'executorRunTime': 112,
#   'executorCpuTime': 107303000,
#   'resultSize': 4037,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 2,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 2000,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 118000,
#   'shuffleReadBytes': 118000,
#   'shuffleReadRecords': 2000,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'description': 'spill',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [38, 37, 36],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'SKIPPED',
#   'stageId': 14,
#   'attemptId': 0,
#   'numTasks': 2000,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 0,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 0,
#   'executorDeserializeTime': 0,
#   'executorDeserializeCpuTime': 0,
#   'executorRunTime': 0,
#   'executorCpuTime': 0,
#   'resultSize': 0,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 0,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [35, 26, 31, 32, 34, 30, 33, 29, 28, 27],
# ...
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 4,
#   'attemptId': 0,
#   'numTasks': 10,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 10,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 10,
#   'submissionTime': '2024-06-06T21:50:06.185GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:50:06.218GMT',
#   'completionTime': '2024-06-06T21:50:13.035GMT',
#   'executorDeserializeTime': 625,
#   'executorDeserializeCpuTime': 101276000,
#   'executorRunTime': 61289,
#   'executorCpuTime': 22715748000,
#   'resultSize': 35182,
#   'jvmGcTime': 12224,
#   'resultSerializationTime': 12,
#   'memoryBytesSpilled': 419430400,
#   'diskBytesSpilled': 141778537,
#   'peakExecutionMemory': 230686720,
#   'inputBytes': 10213600,
#   'inputRecords': 1006,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 51790283,
#   'shuffleWriteTime': 2093506662,
#   'shuffleWriteRecords': 10000000,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'description': 'spill',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [20, 7, 3, 19, 17, 4, 5, 16, 6, 1, 0, 2, 18],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 572080456,
#    'JVMOffHeapMemory': 140021736,
#    'OnHeapExecutionMemory': 157614080,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 10271193,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 167885273,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 10493961,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 39,
#    'MinorGCTime': 459,
#    'MajorGCCount': 9,
#    'MajorGCTime': 624,
#    'TotalGCTime': 1083},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 3,
#   'attemptId': 0,
#   'numTasks': 1,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 1,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 1,
#   'submissionTime': '2024-06-06T21:50:05.562GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:50:05.590GMT',
#   'completionTime': '2024-06-06T21:50:05.772GMT',
#   'executorDeserializeTime': 39,
#   'executorDeserializeCpuTime': 36808000,
#   'executorRunTime': 106,
#   'executorCpuTime': 96250000,
#   'resultSize': 4038,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 8,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 10,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 581,
#   'shuffleReadBytes': 581,
#   'shuffleReadRecords': 10,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'description': 'spill',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [15, 14, 13],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'SKIPPED',
#   'stageId': 2,
#   'attemptId': 0,
#   'numTasks': 10,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 0,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 0,
#   'executorDeserializeTime': 0,
#   'executorDeserializeCpuTime': 0,
#   'executorRunTime': 0,
#   'executorCpuTime': 0,
#   'resultSize': 0,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 0,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [12, 7, 3, 4, 5, 6, 1, 0, 11, 9, 2, 10, 8],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 1,
#   'attemptId': 0,
#   'numTasks': 10,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 10,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 10,
#   'submissionTime': '2024-06-06T21:50:04.526GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:50:04.614GMT',
#   'completionTime': '2024-06-06T21:50:05.313GMT',
#   'executorDeserializeTime': 2259,
#   'executorDeserializeCpuTime': 359506000,
#   'executorRunTime': 2758,
#   'executorCpuTime': 549914000,
#   'resultSize': 25600,
#   'jvmGcTime': 0,
#   'resultSerializationTime': 68,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 10213600,
#   'inputRecords': 1006,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 581,
#   'shuffleWriteTime': 104987658,
#   'shuffleWriteRecords': 10,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'description': 'spill',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [12, 7, 3, 4, 5, 6, 1, 0, 11, 9, 2, 10, 8],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0},
#  {'status': 'COMPLETE',
#   'stageId': 0,
#   'attemptId': 0,
#   'numTasks': 10,
#   'numActiveTasks': 0,
#   'numCompleteTasks': 10,
#   'numFailedTasks': 0,
#   'numKilledTasks': 0,
#   'numCompletedIndices': 10,
#   'submissionTime': '2024-06-06T21:49:58.583GMT',
#   'firstTaskLaunchedTime': '2024-06-06T21:49:59.370GMT',
#   'completionTime': '2024-06-06T21:50:04.258GMT',
#   'executorDeserializeTime': 20365,
#   'executorDeserializeCpuTime': 2895961000,
#   'executorRunTime': 25174,
#   'executorCpuTime': 6187023000,
#   'resultSize': 18360,
#   'jvmGcTime': 2670,
#   'resultSerializationTime': 252,
#   'memoryBytesSpilled': 0,
#   'diskBytesSpilled': 0,
#   'peakExecutionMemory': 0,
#   'inputBytes': 0,
#   'inputRecords': 0,
#   'outputBytes': 0,
#   'outputRecords': 0,
#   'shuffleRemoteBlocksFetched': 0,
#   'shuffleLocalBlocksFetched': 0,
#   'shuffleFetchWaitTime': 0,
#   'shuffleRemoteBytesRead': 0,
#   'shuffleRemoteBytesReadToDisk': 0,
#   'shuffleLocalBytesRead': 0,
#   'shuffleReadBytes': 0,
#   'shuffleReadRecords': 0,
#   'shuffleCorruptMergedBlockChunks': 0,
#   'shuffleMergedFetchFallbackCount': 0,
#   'shuffleMergedRemoteBlocksFetched': 0,
#   'shuffleMergedLocalBlocksFetched': 0,
#   'shuffleMergedRemoteChunksFetched': 0,
#   'shuffleMergedLocalChunksFetched': 0,
#   'shuffleMergedRemoteBytesRead': 0,
#   'shuffleMergedLocalBytesRead': 0,
#   'shuffleRemoteReqsDuration': 0,
#   'shuffleMergedRemoteReqsDuration': 0,
#   'shuffleWriteBytes': 0,
#   'shuffleWriteTime': 0,
#   'shuffleWriteRecords': 0,
#   'name': 'count at NativeMethodAccessorImpl.java:0',
#   'description': 'spill',
#   'details': 'org.apache.spark.sql.Dataset.count(Dataset.scala:3613)\nsun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)\nsun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)\nsun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)\njava.lang.reflect.Method.invoke(Method.java:498)\npy4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)\npy4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)\npy4j.Gateway.invoke(Gateway.java:282)\npy4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)\npy4j.commands.CallCommand.execute(CallCommand.java:79)\npy4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)\npy4j.ClientServerConnection.run(ClientServerConnection.java:106)\njava.lang.Thread.run(Thread.java:750)',
#   'schedulingPool': 'default',
#   'rddIds': [7, 3, 4, 5, 6, 1, 0, 2],
#   'accumulatorUpdates': [],
#   'killedTasksSummary': {},
#   'resourceProfileId': 0,
#   'peakExecutorMetrics': {'JVMHeapMemory': 0,
#    'JVMOffHeapMemory': 0,
#    'OnHeapExecutionMemory': 0,
#    'OffHeapExecutionMemory': 0,
#    'OnHeapStorageMemory': 0,
#    'OffHeapStorageMemory': 0,
#    'OnHeapUnifiedMemory': 0,
#    'OffHeapUnifiedMemory': 0,
#    'DirectPoolMemory': 0,
#    'MappedPoolMemory': 0,
#    'ProcessTreeJVMVMemory': 0,
#    'ProcessTreeJVMRSSMemory': 0,
#    'ProcessTreePythonVMemory': 0,
#    'ProcessTreePythonRSSMemory': 0,
#    'ProcessTreeOtherVMemory': 0,
#    'ProcessTreeOtherRSSMemory': 0,
#    'MinorGCCount': 0,
#    'MinorGCTime': 0,
#    'MajorGCCount': 0,
#    'MajorGCTime': 0,
#    'TotalGCTime': 0},
#   'isShufflePushEnabled': False,
#   'shuffleMergersCount': 0}]
